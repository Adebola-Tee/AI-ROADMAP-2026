# %% [markdown]
# # First practical ML foundation coding day
# features=X (the input column)
# target/label=y (the answer column)

# %%
import pandas as pd

# %%
data = {
    "study_hours": [2,4,6,8],
    "attendance":[60,75,90,95],
    "score":[45,64,85,92]
}
df=pd.DataFrame(data)
df
# Out:
#    study_hours  attendance  score
# 0            2          60     45
# 1            4          75     64
# 2            6          90     85
# 3            8          95     92

# %%
X =df[["study_hours", "attendance"]]
y=df["score"]
print("Features:")
print(X)
print("Target:")
print(y)
# Out:
# Features:
#    study_hours  attendance
# 0            2          60
# 1            4          75
# 2            6          90
# 3            8          95
# Target:
# 0    45
# 1    64
# 2     5
# 3    92
# Name: score, dtype: int64
