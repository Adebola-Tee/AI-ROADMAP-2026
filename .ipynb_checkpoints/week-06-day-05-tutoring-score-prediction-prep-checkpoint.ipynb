# %% [markdown]
# # Features = X
# # Target = y
# # Task type = regression

# %%
import pandas as pd
data = {
    "practice_hours": [1, 2, 3, 4, 5],
    "attendance": [60, 70, 80, 90, 95],
    "homework_score": [45, 55, 65, 78, 88],
    "final_score": [50, 58, 70, 82, 90]
}
df=pd.DataFrame(data)
df
# Out:
#    practice_hours  attendance  homework_score  final_score
# 0               1          60              45           50
# 1               2          70              55           58
# 2               3          80              65           70
# 3               4          90              78           82
# 4               5          95              88           90

# %%
X =df[["practice_hours", "attendance", "homework_score"]]
y = df["final_score"]
print("Features:")
print(X)
print("Target:")
print(y)
# Out:
# Features:
#    practice_hours  attendance  homework_score
# 0               1          60              45
# 1               2          70              55
# 2               3          80              65
# 3               4          90              78
# 4               5          95              88
# Target:
# 0    50
# 1    58
# 2    70
# 3    82
# 4    90
# Name: final_score, dtype: int64
