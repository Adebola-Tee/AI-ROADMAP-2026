# %%
import pandas as pd

# %%
data = {
    "day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"],
    "lessons": [3, 5, 2, 4, 6],
    "hours_worked": [3.0, 4.5, 2.0, 4.0, 5.5],
    "income":[18000, 30000, 12000, 24000, 36000]
}

df=pd.DataFrame(data)
df
# Out:
#          day  lessons  hours_worked  income
# 0     Monday        3           3.0   18000
# 1    Tuesday        5           4.5   30000
# 2  Wednesday        2           2.0   12000
# 3   Thursday        4           4.0   24000
# 4     Friday        6           5.5   36000

# %% [markdown]
# ### Data analysis
# Examining data to answer questions

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# Inestigating data before making conclusion

# %% [markdown]
# ### Observation
# Something directly visible in the data

# %% [markdown]
# ### Insight
# A useful explanation on what the observation might mean.

# %% [markdown]
# ### Data story
# Combining numbers, charts, and explanation to communicate a finding
