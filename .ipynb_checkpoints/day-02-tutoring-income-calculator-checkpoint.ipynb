# %%
students = 10
hourly_charge =15
per_session_hour = 1
weekly_income = students * hourly_charge * per_session_hour 
print (weekly_income)
# Out:
# 150

# %% [markdown]
# ## Test running my weekly earning

# %%
students = 10
hourly_charge = 15
per_session_hour = 1
weekly_income = students * hourly_charge * per_session_hour 
monthly_income = weekly_income * 4
print ("Estimate monthly income £",monthly_income)
# Out:
# Estimate monthly income £ 600
