# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\taiwo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = {
    "day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"],
    "lessons": [3, 5, 2, 4, 6],
    "hours_worked": [3.0, 4.5, 2.0, 4.0, 5.5],
    "income": [18000, 30000, 12000, 24000, 36000]
}

df = pd.DataFrame(data)
df
# Out:
#          day  lessons  hours_worked  income
# 0     Monday        3           3.0   18000
# 1    Tuesday        5           4.5   30000
# 2  Wednesday        2           2.0   12000
# 3   Thursday        4           4.0   24000
# 4     Friday        6           5.5   36000

# %%
df.head()
# Out:
#          day  lessons  hours_worked  income
# 0     Monday        3           3.0   18000
# 1    Tuesday        5           4.5   30000
# 2  Wednesday        2           2.0   12000
# 3   Thursday        4           4.0   24000
# 4     Friday        6           5.5   36000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   day           5 non-null      str
#  1   lessons       5 non-null      int64
#  2   hours_worked  5 non-null      float64
#  3   income        5 non-null      int64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#         lessons  hours_worked        income
# count  5.000000      5.000000      5.000000
# mean   4.000000      3.800000  24000.000000
# std    1.581139      1.350926   9486.832981
# min    2.000000      2.000000  12000.000000
# 25%    3.000000      3.000000  18000.000000
# 50%    4.000000      4.000000  24000.000000
# 75%    5.000000      4.500000  30000.000000
# max    6.000000      5.500000  36000.000000

# %%
df.isnull().sum()
# Out:
# day             0
# lessons         0
# hours_worked    0
# income          0
# dtype: int64

# %%
df
# Out:
#          day  lessons  hours_worked  income
# 0     Monday        3           3.0   18000
# 1    Tuesday        5           4.5   30000
# 2  Wednesday        2           2.0   12000
# 3   Thursday        4           4.0   24000
# 4     Friday        6           5.5   36000

# %%
plt.bar(df["day"], df["income"])
plt.title("Tutoring Income by Day")
plt.xlabel("Day")
plt.ylabel("Income")
plt.show()
