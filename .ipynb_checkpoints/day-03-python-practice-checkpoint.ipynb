# %% [markdown]
# # Exercise 1 — Weekly tutoring income

# %%
number_of_students = 24
hourly_rate = 20
hours_per_students_per_week = 2
weekly_income = number_of_students * hourly_rate * hours_per_students_per_week
print ("weekly tutoring income is £",weekly_income)
# Out:
# weekly tutoring income is £ 960

# %% [markdown]
# # Exercise 2 — Monthly tutoring income

# %%
number_of_students = 24
hourly_rate = 20
hours_per_students_per_week = 2
weekly_income = number_of_students * hourly_rate * hours_per_students_per_week
monthly_income =  weekly_income * 4
print ("monthly tutoring income is £",monthly_income)
# Out:
# monthly tutoring income is £ 3840

# %% [markdown]
# # Exercise 3 — Income from one student

# %%
per_student = 1
weekly_classes = 2
price_per_week = weekly_classes *20
monthly_pay= price_per_week * 4
print ("Montly Income from one student is £",monthly_pay)
# Out:
# Montly Income from one student is £ 160

# %% [markdown]
# # Exercise 4 — Redbubble upload target

# %%
uploads_per_day = 20
number_of_days = 30
total_number_of_uploads = uploads_per_day * number_of_days 
print (total_number_of_uploads)
# Out:
# 600

# %% [markdown]
# # Exercise 5 — AI study hours

# %%
study_hours_per_day = 1
number_of_days_in_a_week = 7
total_weekly_study = study_hours_per_day * number_of_days_in_a_week
print(total_weekly_study, "hours")
# Out:
# 7 hours

# %% [markdown]
# # Exercise 6 — Savings goal

# %%
monthly_income = 2000
monthly_spending = 230
money_left = monthly_income - monthly_spending
print("£", money_left)
# Out:
# £ 1770

# %% [markdown]
# # Exercise 7 — Travel budget split

# %%
total_hotel_cost = 400
number_of_people_sharing = 2
payment_per_person = total_hotel_cost / number_of_people_sharing
print ("£",payment_per_person)
# Out:
# £ 200.0

# %% [markdown]
# # Exercise 8 — Lesson package price

# %%
number_of_lessons = 8
price_per_lesson = 20
lesson_package_price = number_of_lessons * price_per_lesson
print("£",lesson_package_price)
# Out:
# £ 160

# %% [markdown]
# # Exercise 9 — Personal introduction

# %%
my_name = "Taiwo"
my_goal = "never miss a day in my 6 months AI/ML learning journey."
my_current_learning_topic = "self-practing coding with Python using Jupyter Notebook."
print ("My name is", my_name + ". My goal is to", my_goal, "I am currently",my_current_learning_topic)
# Out:
# My name is Taiwo. My goal is to never miss a day in my 6 months AI/ML learning journey. I am currently self-practing coding with Python using Jupyter Notebook.

# %% [markdown]
# # Exercise 10 — Day 3 reflection inside Python

# %%
day = 3
topic = "self-practing coding with Python using Jupyter Notebook"
status = "complete"
print ("day", day, topic, status)
# Out:
# day 3 self-practing coding with Python using Jupyter Notebook complete

# %%
my_name = "Taiwo"
my_goal = "never miss a day in my 6 months AI/ML learning journey"
my_current_learning_topic = "self-practing coding with Python using Jupyter Notebook."
print (f"My name is {my_name}. My goal is to {my_goal}. I am currently {my_current_learning_topic}")
# Out:
# My name is Taiwo. My goal is to never miss a day in my 6 months AI/ML learning journey. I am currently self-practing coding with Python using Jupyter Notebook.
