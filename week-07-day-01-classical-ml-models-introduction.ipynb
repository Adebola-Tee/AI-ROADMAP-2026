# %% [markdown]
# # Classical ML Model Instruction

# %% [markdown]
# # Linear Regression --->>> Using a straight-line pattern to predict pnumber

# %% [markdown]
# # Logistic Regression --->>>  Predicting category like yes/no pass/fail true/false

# %% [markdown]
# # Decision Tree - It is like a strict teacher that asks every question one by one. Therefore, it asks questions to make a decision

# %% [markdown]
# # Random Forest --->>> This is where we have different decision trees, more like many trees voting for stronger decisions

# %% [markdown]
# # K-Nearest Neighbors --->>> Predict by looking at closest/similar examples
